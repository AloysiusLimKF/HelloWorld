# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %reload_ext autoreload 
# %autoreload
import plotly.express as px
import scipy as sp

# %%
from scipy.optimize import minimize

def f(x):
	return (x-3)**2

res = minimize(f, 2)
# must give it an initial guess of x which doesn't have to be very good
res
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 5.551437397369767e-17
#         x: [ 3.000e+00]
#       nit: 2
#       jac: [-4.325e-13]
#  hess_inv: [[ 5.000e-01]]
#      nfev: 6
#      njev: 3
